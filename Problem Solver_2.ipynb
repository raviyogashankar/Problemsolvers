# %% [markdown]
# ### 1.What are the two values of the Boolean data type? How do you write them?

# %%
print("Boolean Data types are:",True,False)
# Out:
# Boolean Data types are: True False

# %% [markdown]
# ### 2. What are the three different types of Boolean operators?

# %%
print("Three different types of Boolean operators {}, {}, {}".format('AND','OR','NOT'))
# Out:
# Three different types of Boolean operators AND, OR, NOT

# %% [markdown]
# ### 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

# %%
And_val = [True and True,True and False,False and True, False and False]
Res_And = []
for i in And_val:
    Res_And.append(i)
print(Res_And)
# Out:
# [True, False, False, False]

# %%
Or_val = [True or True,True or False,False or True, False or False]
Res_Or = []
for i in Or_val:
    Res_Or.append(i)
print(Res_Or)
# Out:
# [True, True, True, False]

# %%
print(not(True))
print(not(False))
# Out:
# False
# True

# %% [markdown]
# ### 4. What are the values of the following expressions?

# %%
print((5 > 4) and (3 == 5) ) #False
print(not (5 > 4)) #False
print((5 > 4) or (3 == 5)) #True
print(not ((5 > 4) or (3 == 5)))#False
print((True and True) and (True == False))#False
print((not False) or (not True))#True
# Out:
# False
# False
# True
# False
# False
# True

# %% [markdown]
# ### 5. What are the six comparison operators?

# %%
print('==') #Equals
print('!=') #Not Equals
print(">") #Greaterthan
print("<") #Lesserthan
print(">=") #Greaterthan equals
print("<=") #Lessthanequals
# Out:
# ==
# !=
# >
# <
# >=
# <=

# %% [markdown]
# ### 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.

# %%
a = 100
print(a)
# Value 100 is assigned to a variable a
print(6 == 6) # comparing two values then we use equal
# Out:
# 100
# True

# %% [markdown]
# ### 7. Identify the three blocks in this code:

# %%
spam = 0
if spam == 10:
    print('eggs')
if spam > 5:
    print('bacon')
else:
    print('ham')
    print('spam')
print('spam') 
# spam does not satisfy the if conditions hence else block is executed
# Out:
# ham
# spam
# spam

# %% [markdown]
# ### 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

# %%
spam = int(input("Please enter a input "))
if spam == 1:
    print("Hello")
elif spam == 2:
    print("Howdy")
else:
    print("Greetings!")
# Out:
# Please enter a input 3
# Greetings!

# %% [markdown]
# ### 9. If your programme is stuck in an endless loop, what keys you’ll press?

# %%
c = 0
while True:
    print("hello")
    c = c+1
# Click on the stop button or press Ctrl+c in terminal
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %% [markdown]
# ### 10. How can you tell the difference between break and continue?

# %%
# Break is used to exit the loop upon satisfying the condition
for i in range(10):
    if i == 5:
        print(i)
        break
    print("Outside the condition",i)
# Out:
# Outside 0
# Outside 1
# Outside 2
# Outside 3
# Outside 4
# 5

# %%
# Continue is used, when a specific condition is met then the code will not execute the next steps and the next iteration will be started
list_a = [1,2,3,4,5,"Data",6,56]
for i in list_a:
    if i == "Data":
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 56

# %% [markdown]
# ### 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

# %%
# All the three are same just the notation is different with Start ,End,Step size
print(range(10))# Only end is specified, defaultstep size is considered
print(range(0,10))# Start & end is specified, defaultstep size is considered
print(range(0,10,1))# Start,end,stepsize is specified
# Out:
# range(0, 10)
# range(0, 10)
# range(0, 10)

# %% [markdown]
# ### 12.12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# %%
for i in range(1,11):
    print("This the iteration for", i)
# Out:
# This the iteration for 1
# This the iteration for 2
# This the iteration for 3
# This the iteration for 4
# This the iteration for 5
# This the iteration for 6
# This the iteration for 7
# This the iteration for 8
# This the iteration for 9
# This the iteration for 10

# %%
c = 0
while c <= 10:
    print("This is the iteration for",c)
    c = c+1
# Out:
# This is the iteration for 0
# This is the iteration for 1
# This is the iteration for 2
# This is the iteration for 3
# This is the iteration for 4
# This is the iteration for 5
# This is the iteration for 6
# This is the iteration for 7
# This is the iteration for 8
# This is the iteration for 9
# This is the iteration for 10

# %% [markdown]
# ### 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

# %%
#import spam
#spam.bacon()

# %%
import math #math module
math.sqrt(10) #called sqrtfunction
# Out:
# 3.1622776601683795
